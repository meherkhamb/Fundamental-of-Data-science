# %%
import numpy as np

# %%
arr = np.array([2,5,6,8,9,5,5])

# %%
arr.max()
# Out:
# np.int64(9)

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
reshaped = arr.reshape(2, 3)

print("Original:", arr)
print("Reshaped:\n", reshaped)
# Out:
# Original: [1 2 3 4 5 6]
# Reshaped:
#  [[1 2 3]
#  [4 5 6]]

# %%
arr.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.linspace(start, stop, num=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 np.linspace(start, stop, num=50)
#
# NameError: name 'start' is not defined

# %%
arr.linspace(0,1,5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 arr.linspace(0,1,5)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'linspace'

# %%
np.swapaxes(a, 0, 0)

# %%
reshaped = arr.reshape(5,6,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 reshaped = arr.reshape(5,6,5)
#
# ValueError: cannot reshape array of size 7 into shape (5,6,5)

# %%
import numpy as np

arr = np.array([2,5,6,8,9,5,5])

arr.max()

arr = np.array([1, 2, 3, 4, 5, 6])
reshaped = arr.reshape(2, 3)

print("Original:", arr)
print("Reshaped:\n", reshaped)

arr.reshape(2,3)

np.linspace(start, stop, num=50)

arr.linspace(0,1,5)

np.swapaxes(a, 0, 0)

reshaped = arr.reshape(5,6,5) 

a = np.array([2,5,6,8,9,5,5])
b = np.swapaxes(2,5,6,)
print("orignal array",a)

arr.shape
# Out:
# Original: [1 2 3 4 5 6]
# Reshaped:
#  [[1 2 3]
#  [4 5 6]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 15
#      11 print("Reshaped:\n", reshaped)
#      13 arr.reshape(2,3)
# ---> 15 np.linspace(start, stop, num=50)
#      17 arr.linspace(0,1,5)
#      19 np.swapaxes(a, 0, 0)
#
# NameError: name 'start' is not defined

# %%
arr.shape
# Out:
# (7,)
